# %%
from taxcalc import *
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, hplot
from bokeh.charts import Scatter
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="78334e34-68c2-44d9-99b8-90980fd2d01b">Loading BokehJS ...</span>
#     </div>

# %%
# Calculator with adjustments
recs = Records()
policy = Policy()
calc = Calculator(policy=policy, records=recs)
calc.advance_to_year(2014)
calc.calc_all()
# Out:
# taxcalc/behavior.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   val = values[year]
# You loaded data for 2009.
# Your data have been extrapolated to 2013.

# %%
# Calculator without adjustments
recs_none = Records(adjust_factors='taxcalc/adjustmentFactors_ones.csv')
policy_none = Policy()
calc_none = Calculator(policy=policy_none, records=recs_none)
calc_none.advance_to_year(2014)
calc_none.calc_all()
# Out:
# You loaded data for 2009.
# Your data have been extrapolated to 2013.

# %%
# Read comparison SOI data
soi = pd.read_csv('soi_data.csv')

# %%
def distribution(item, weight, agi):
    agi_1 = (((item[agi < 0] * weight[agi < 0]).sum() / 1000))
    agi_2 = ((item[(agi > 1) & (agi < 5000)] * weight[(agi > 1) & (agi < 5000)]).sum() / 1000)
    agi_3 = ((item[(agi > 5000) & (agi < 10000)] * weight[(agi > 5000) & (agi < 10000)]).sum() / 1000)
    agi_4 = ((item[(agi > 10000) & (agi < 15000)] * weight[(agi > 10000) & (agi < 15000)]).sum() / 1000)
    agi_5 = ((item[(agi > 15000) & (agi < 20000)] * weight[(agi > 15000) & (agi < 20000)]).sum() / 1000)
    agi_6 = ((item[(agi > 20000) & (agi < 25000)] * weight[(agi > 20000) & (agi < 25000)]).sum() / 1000)
    agi_7 = ((item[(agi > 25000) & (agi < 30000)] * weight[(agi > 25000) & (agi < 30000)]).sum() / 1000)
    agi_8 = ((item[(agi > 30000) & (agi < 40000)] * weight[(agi > 30000) & (agi < 40000)]).sum() / 1000)
    agi_9 = ((item[(agi > 40000) & (agi < 50000)] * weight[(agi > 40000) & (agi < 50000)]).sum() / 1000)
    agi_10 = ((item[(agi > 50000) & (agi < 75000)] * weight[(agi > 50000) & (agi < 75000)]).sum() / 1000)
    agi_11 = ((item[(agi > 75000) & (agi < 100000)] * weight[(agi > 75000) & (agi < 100000)]).sum() / 1000)
    agi_12 = ((item[(agi > 100000) & (agi < 200000)] * weight[(agi > 100000) & (agi < 200000)]).sum() / 1000)
    agi_13 = ((item[(agi > 200000) & (agi < 500000)] * weight[(agi > 200000) & (agi < 500000)]).sum() / 1000)
    agi_14 = ((item[(agi > 500000) & (agi < 1000000)] * weight[(agi > 500000) & (agi < 1000000)]).sum() / 1000)
    agi_15 = ((item[(agi > 1000000) & (agi < 1500000)] * weight[(agi > 1000000) & (agi < 1500000)]).sum() / 1000)
    agi_16 = ((item[(agi > 1500000) & (agi < 2000000)] * weight[(agi > 1500000) & ( agi < 2000000)]).sum() / 1000)
    agi_17 = ((item[(agi > 2000000) & (agi < 5000000)] * weight[(agi > 2000000) & ( agi < 5000000)]).sum() / 1000)
    agi_18 = ((item[(agi > 5000000) & (agi < 10000000)] * weight[(agi > 5000000) & ( agi < 10000000)]).sum() / 1000)
    agi_19 = ((item[agi > 10000000] * weight[agi > 10000000]).sum() / 1000)
    df = [agi_1, agi_2, agi_3, agi_4, agi_5, agi_6, agi_7, agi_8, agi_9, agi_10, agi_11,
                       agi_12, agi_13, agi_14, agi_15, agi_16, agi_17, agi_18, agi_19]
    return df

# %%
# Find totals for each item in original calculator
tc = pd.DataFrame()
tc['AGI'] = distribution(calc.records.c00100, calc.records.s006, calc.records.c00100)
tc['Wages'] = distribution(calc.records.e00200, calc.records.s006, calc.records.c00100)
tc['Interest'] = distribution(calc.records.e00300, calc.records.s006, calc.records.c00100)
tc['Dividends'] = distribution(calc.records.e00650, calc.records.s006, calc.records.c00100)
tc['SchC'] = distribution(calc.records.e00900, calc.records.s006, calc.records.c00100)
tc['IRA'] = distribution(calc.records.e01400, calc.records.s006, calc.records.c00100)
tc['Scorp'] = distribution(calc.records.e26270, calc.records.s006, calc.records.c00100)
tc['SS Benefits'] = distribution(calc.records.e02400, calc.records.s006, calc.records.c00100)
tc['Item Ded'] = distribution(calc.records.c04470, calc.records.s006, calc.records.c00100)
tc['Inc'] = distribution(calc.records.c04800, calc.records.s006, calc.records.c00100)

# %%
# Find totals for each item in calculator with no adjustment
tc_none = pd.DataFrame()
tc_none['AGI'] = distribution(calc_none.records.c00100, calc_none.records.s006, calc_none.records.c00100)
tc_none['Wages'] = distribution(calc_none.records.e00200, calc_none.records.s006, calc_none.records.c00100)
tc_none['Interest'] = distribution(calc_none.records.e00300, calc_none.records.s006, calc_none.records.c00100)
tc_none['Dividends'] = distribution(calc_none.records.e00650, calc_none.records.s006, calc_none.records.c00100)
tc_none['SchC'] = distribution(calc_none.records.e00900, calc_none.records.s006, calc_none.records.c00100)
tc_none['IRA'] = distribution(calc_none.records.e01400, calc_none.records.s006, calc_none.records.c00100)
tc_none['Scorp'] = distribution(calc_none.records.e26270, calc_none.records.s006, calc_none.records.c00100)
tc_none['SS Benefits'] = distribution(calc_none.records.e02400, calc_none.records.s006, calc_none.records.c00100)
tc_none['Item Ded'] = distribution(calc_none.records.c04470, calc_none.records.s006, calc_none.records.c00100)
tc_none['Inc'] = distribution(calc_none.records.c04800, calc_none.records.s006, calc_none.records.c00100)

# %%
index_list = ['Zero or Negative',
              '$1-$5K',
              '$5K-$10K',
              '$10K-$15K',
              '$15K-$20K',
              '$20K-$25K',
              '$25K-$30K',
              '$30K-$40K',
              '$40K-$50K',
              '$50K-$75K',
              '$75K-$100K',
              '$100K-$200K',
              '$200K-$500K',
              '$500K-$1M',
              '$1M-$1.5M',
              '$1.5M-$2M',
              '$2M-$5M',
              '$5M-$10M',
              '$10M and over']
results.index = index_list

# %% [markdown]
# # AGI Distribution

# %%
soi_agi = pd.DataFrame()
soi_agi['Percent of Total AGI'] = soi['AGI'] / soi['AGI'].sum() * 100
soi_agi['Measure'] = 'SOI'
soi_agi['AGI Bin'] = index_list
tc_agi = pd.DataFrame()
tc_agi['Percent of Total AGI'] = tc['AGI'] / tc['AGI'].sum() * 100
tc_agi['Measure'] = 'TC-Adjustment'
tc_agi['AGI Bin'] = index_list
tc_none_agi = pd.DataFrame()
tc_none_agi['Percent of Total AGI'] = tc_none['AGI'] / tc_none['AGI'].sum() * 100
tc_none_agi['Measure'] = 'TC-No Adjustment'
tc_none_agi['AGI Bin'] = index_list
data_agi = [soi_agi, tc_agi, tc_none_agi]
plot_data_agi = pd.concat(data_agi)
plot_agi = Scatter(plot_data_agi, x='AGI Bin', y='Percent of Total AGI', color='Measure', 
                   title='Percent of Total AGI by AGI Bin')
show(plot_agi)

soi_agi_sum = pd.DataFrame()
soi_agi_sum['Total AGI'] = soi['AGI']
soi_agi_sum['Measure'] = 'SOI'
soi_agi_sum['AGI Bin'] = index_list
tc_agi_sum = pd.DataFrame()
tc_agi_sum['Total AGI'] = tc['AGI']
tc_agi_sum['Measure'] = 'TC'
tc_agi_sum['AGI Bin'] = index_list
tc_none_agi_sum = pd.DataFrame()
tc_none_agi_sum['Total AGI'] = tc_none['AGI']
tc_none_agi_sum['Measure'] = 'tc_none'
tc_none_agi_sum['AGI Bin'] = index_list
data_agi_sum = [soi_agi_sum, tc_agi_sum, tc_none_agi_sum]
plot_data_agi_sum = pd.concat(data_agi_sum)
plot_agi_sum = Scatter(plot_data_agi_sum, x='AGI Bin', y='Total AGI', color='Measure', 
                   title='Total AGI by AGI Bin (Thousand of Dollars)')
show(plot_agi_sum)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a89b07d1-1f82-4fc6-8c41-fdfa3a713e8d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a89b07d1-1f82-4fc6-8c41-fdfa3a713e8d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a89b07d1-1f82-4fc6-8c41-fdfa3a713e8d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a89b07d1-1f82-4fc6-8c41-fdfa3a713e8d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f7466c41-ab44-4675-be2f-e459dbac9fc4":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment","TC-No Adjustment"],"chart_index":[{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"},{"Measure":"TC-No Adjustment"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":[-1.330827250929516,0.4109662066737458,1.0615937901441899,1.651379822901889,1.9950952239763433,2.045806005581049,2.4597029836295623,4.804025946536763,4.938514912706158,12.312467219251635,10.661822125118368,24.42754671162476,15.274935429002321,5.92092306872124,2.574991497348061,1.4365443526694768,3.5854360337164133,2.1240598103292245,3.6450161109983323]}},"id":"9d99bc72-f0f5-4cdd-8438-8c17492baf3e","type":"ColumnDataSource"},{"attributes":{},"id":"6ddee0ce-285c-4b5f-bbb9-a7b87b06ae09","type":"CategoricalTicker"},{"attributes":{"items":[{"id":"a1ccdc56-42ef-466a-bca2-09024006a96a","type":"LegendItem"},{"id":"aca12878-bca8-4c0b-96be-1fb9e9c0e9b6","type":"LegendItem"},{"id":"d4c993b9-921b-4524-84ce-5099299e8a46","type":"LegendItem"}],"location":"top_left","plot":{"id":"6c9f40a1-7845-467d-8dc1-2682ed3065e4","subtype":"Chart","type":"Plot"}},"id":"8cee8b81-eb5f-4836-b844-204df9065b44","type":"Legend"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment","TC-Adjustment"],"chart_index":[{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"},{"Measure":"TC-Adjustment"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":[-1.3343614806661326,0.406308811285529,1.0538430567345447,1.6536244044407586,1.9961938425745478,2.0266582255764174,2.455782952620599,4.80560727787466,4.925273821450749,12.231994229768127,10.58787182425589,24.356104171224715,15.273804421267545,5.947774760227282,2.5705620447094786,1.443106611382018,3.6137817503155207,2.1376441264579666,3.848425148499775]}},"id":"b0eea8f8-87c7-4580-bd78-8ec0cc20041b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"44d4d3ad-03ed-4 ...
#     <div class="bk-root">
#         <div class="plotdiv" id="52675665-5015-4fa8-a50d-30abcc195e9e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#52675665-5015-4fa8-a50d-30abcc195e9e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("52675665-5015-4fa8-a50d-30abcc195e9e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '52675665-5015-4fa8-a50d-30abcc195e9e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"061a0f87-f0e9-4199-b6b7-449b24f1df90":{"roots":{"references":[{"attributes":{"callback":null,"end":2625499658.657815,"start":-454344472.6052559},"id":"d64abd65-6799-4aab-bd9c-4e7636d72f4c","type":"Range1d"},{"attributes":{"label":{"value":"SOI"},"renderers":[{"id":"f60e8c3b-221f-40ad-a9e0-c9484f019dbc","type":"GlyphRenderer"}]},"id":"6994a0c5-8e47-4738-b5df-a5d1e8f834ea","type":"LegendItem"},{"attributes":{},"id":"e277619b-3fbc-40ad-aba2-d51318a79622","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI"],"chart_index":[{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":[-197690795.0,26379097.0,89719121.0,153830822.0,197774439.0,226042578.0,241769583.0,507486039.0,513959724.0,1191956661.0,1111626170.0,2361756261.0,1419776711.0,562622816.0,217426739.0,132463053.0,326511879.0,181943504.0,505681010.0]}},"id":"16d2f1b7-717e-4213-b0cf-7ed4fe304cba","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f27714a7-d147-4f6f-88ec-e535e79f0030","type":"ColumnDataSource"},"glyph":{"id":"fb285313-e378-4ac3-9d98-7931ad4dcdbb","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"52bb5b7b-208e-4d96-9678-820f439be546","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"]},"id":"bd124295-d2c9-4a2e-9101-05746a72809c","type":"FactorRange"},{"attributes":{"plot":{"id":"fd3c387a-b0e1-46cf-8958-7263222f6956","subtype":"Chart","type":"Plot"}},"id":"984515b6-eb26-49a2-a60b-515245589a8e","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none","tc_none"],"chart_index":[{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"},{"Measure":"tc_none"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":[-129056135.76574853,39853189.455338724,102947390.21404384,160141519.85270053,193473104.72583959,198390750.88238853,238528150.0487744,465867395.144934,478909378.0655797,1193993765.8694854,1033923495.8770864,2368845981.052559,1481277257.5565271,574177791.2059836,249708181.16723397,139307985.2265892,347695404.66166735,205979364.38779515,353473145.1890413]}},"id":"8350f5f1-62da-4575-b8ac-9e2d18848385","type":"ColumnDataSource"},{"attributes":{"axis_label":"Total AGI","formatter":{"id":"e277619b-3fbc-40ad-aba2-d51318a79622","type":"BasicTickFormatter"},"plot":{ ...

# %% [markdown]
# # Interest Income Distribution

# %%
soi_int = pd.DataFrame()
soi_int['Percent of Total Interest Income'] = soi['Interest'] / (soi['Interest'].sum()) * 100
soi_int['Measure'] = 'SOI'
soi_int['AGI Bin'] = index_list
tc_int = pd.DataFrame()
tc_int['Percent of Total Interest Income'] = tc['Interest'] / (tc['Interest'].sum()) * 100
tc_int['Measure'] = 'TC-Adjustment'
tc_int['AGI Bin'] = index_list
tc_none_int = pd.DataFrame()
tc_none_int['Percent of Total Interest Income'] = tc_none['Interest'] / (tc_none['Interest'].sum()) * 100
tc_none_int['Measure'] = 'TC-No Adjustment'
tc_none_int['AGI Bin'] = index_list
data_int = [soi_int, tc_int, tc_none_int]
plot_data_int = pd.concat(data_int)
plot_int = Scatter(plot_data_int, x='AGI Bin', y='Percent of Total Interest Income', color='Measure',
                    title = 'Percent of Total Interest Income by AGI Bin')
show(plot_int)

soi_int_sum = pd.DataFrame()
soi_int_sum['Total Interest Income'] = soi['Interest']
soi_int_sum['Measure'] = 'SOI'
soi_int_sum['AGI Bin'] = index_list
tc_int_sum = pd.DataFrame()
tc_int_sum['Total Interest Income'] = tc['Interest']
tc_int_sum['Measure'] = 'TC-Adjustment'
tc_int_sum['AGI Bin'] = index_list
tc_none_int_sum = pd.DataFrame()
tc_none_int_sum['Total Interest Income'] = tc_none['Interest']
tc_none_int_sum['Measure'] = 'TC-No Adjustment'
tc_none_int_sum['AGI Bin'] = index_list
data_int_sum = [soi_int_sum, tc_int_sum, tc_none_int_sum]
plot_data_int_sum = pd.concat(data_int_sum)
plot_int_sum = Scatter(plot_data_int_sum, x='AGI Bin', y='Total Interest Income', color='Measure',
                    title = 'Total Interest Income by AGI Bin (Thousand of Dollars)')
show(plot_int_sum)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7dbc7074-f89b-4c8e-9346-339d3030393d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7dbc7074-f89b-4c8e-9346-339d3030393d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7dbc7074-f89b-4c8e-9346-339d3030393d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7dbc7074-f89b-4c8e-9346-339d3030393d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c3ed9dc6-5ade-4eb3-85fe-2aa0b49d6ed8":{"roots":{"references":[{"attributes":{"plot":{"id":"4fd2e1f1-9036-4646-94ee-89e32aa3e51b","subtype":"Chart","type":"Plot"},"ticker":{"id":"51e98f4e-c113-4ce5-ad92-339d6262d24b","type":"CategoricalTicker"}},"id":"55f2c62f-cf94-4835-8a05-7c27fd3e6114","type":"Grid"},{"attributes":{"plot":null,"text":"Percent of Total Interest Income by AGI Bin"},"id":"85646070-5697-4d95-b068-d1324c67ea02","type":"Title"},{"attributes":{"below":[{"id":"f809dea0-bd6e-433c-b022-fe7696eded8a","type":"CategoricalAxis"}],"left":[{"id":"554dc94d-7864-4930-966e-233e0d7c6498","type":"LinearAxis"}],"renderers":[{"id":"1f1fadf2-2988-486f-9c98-c8406357b148","type":"BoxAnnotation"},{"id":"a40feac5-73d7-4329-ac9e-7b3760d3f074","type":"GlyphRenderer"},{"id":"5416b92f-b25e-496f-9bdb-884337708922","type":"GlyphRenderer"},{"id":"391cf2e5-5db0-4928-87c6-5f7945324582","type":"GlyphRenderer"},{"id":"da8218d2-64e5-4dc2-9c7c-904e8ceed331","type":"Legend"},{"id":"f809dea0-bd6e-433c-b022-fe7696eded8a","type":"CategoricalAxis"},{"id":"554dc94d-7864-4930-966e-233e0d7c6498","type":"LinearAxis"},{"id":"55f2c62f-cf94-4835-8a05-7c27fd3e6114","type":"Grid"},{"id":"cfcc3c8b-37c5-4d15-b74c-ba5d5b54a0cb","type":"Grid"}],"title":{"id":"85646070-5697-4d95-b068-d1324c67ea02","type":"Title"},"tool_events":{"id":"edfff4a9-423b-4936-83f9-780d701fda2c","type":"ToolEvents"},"toolbar":{"id":"92b85239-a45c-4fa5-9c5d-5aedaae1cc39","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"182d50b4-71a6-4ebe-a889-edd42f634ff7","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"47d8f318-c3b6-41d9-b519-1ce694e5ac17","type":"Range1d"}},"id":"4fd2e1f1-9036-4646-94ee-89e32aa3e51b","subtype":"Chart","type":"Plot"},{"attributes":{"label":{"value":"TC-Adjustment"},"renderers":[{"id":"5416b92f-b25e-496f-9bdb-884337708922","type":"GlyphRenderer"}]},"id":"131dc355-7c3c-42a3-b5ed-e8710677014d","type":"LegendItem"},{"attributes":{"callback":null,"end":23.691075596985357,"start":-1.5244515548634439},"id":"47d8f318-c3b6-41d9-b519-1ce694e5ac17","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"b2225941-4318-4d0a-a976-c783c49031d2","type":"Circle"},{"attributes":{},"id":"69e80b49-1302-4b04-ac38-83b934c34378","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"AGI Bin","formatter":{"id":"69e80b49-1302-4b04-ac38-83b934c34378","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"4fd2e1f1-9036-4646-94ee-89e32aa3e51b","subtype":"Chart","type":"Plot"},"ticker":{"id":"51e98f4e-c113-4ce5-ad92-339d6262d24b","type":"CategoricalTicker"}},"id":"f809dea0-bd6e-433c-b022-fe7696eded8a","type":"CategoricalAxis"},{"attributes":{"dimension":1,"plot":{"id":"4fd2e1f1-9036-4646-94ee-89e32aa3e51b","subtype":"Chart","type":"Plot"},"ticker":{"id":"4c154faa-47e8-4695-b3fb-44a221e9befa","type":"BasicTicker"}},"id":"cfcc3c8b-37c5-4d15-b74c-ba5d5b54a0cb","type":"Grid"},{"attributes":{},"id":"708eeb0c-e63e-4d7d-a3d3-cd7caf8f0083","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"83da696b-89aa-4828-a2de-3a69047e62ac","type":"ColumnDataSource"},"glyph":{"id":"b2225941-4318-4d0a-a976-c783c49031d2","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"391cf2e5-5db0-4928-87c6-5f7945324582","type":"GlyphRenderer"},{"attributes":{"label":{"value":"TC-No Adjustment"},"renderers":[{"id":"391cf2e5-5db0-4928-87c6-5f7945324582","type":"GlyphRenderer"}]},"id":"1ee0dc63-bd0a-4891-b415-8adab1d3debc","type":"LegendItem"},{"attributes":{"plot":{"id":"4fd2e1f1-9036-4646-94ee-89e32aa3e51b","subtype":"Chart","type":"Plot"}},"id":"3a57e798-587e-4cc3-a1ed-b68c1c86b494","type":"ResetTool"},{"attributes":{"data_source":{"id":"ae6e204f-6eb6-489c-9887-9fa0d314ca5e","type":"ColumnDataSource"},"glyph":{"id":"a56e9f27- ...
#     <div class="bk-root">
#         <div class="plotdiv" id="4a10dee3-227f-4761-bf32-07fb33cc868a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4a10dee3-227f-4761-bf32-07fb33cc868a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a10dee3-227f-4761-bf32-07fb33cc868a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a10dee3-227f-4761-bf32-07fb33cc868a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"044e6c8b-a6d2-4a53-bc90-3d19e51b6c8d":{"roots":{"references":[{"attributes":{},"id":"fec9230e-75a4-48e2-ae04-6de22e8b009e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"98eed7ee-f76d-4644-8501-8a93238c5f9e","type":"ColumnDataSource"},"glyph":{"id":"f4cd1cb7-ab43-47ce-8904-4f39f745c855","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6edb7eca-be77-4e9c-9073-722f64894186","type":"GlyphRenderer"},{"attributes":{},"id":"e35a0aa0-106b-4f35-a7a8-c78920159f36","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"f4cd1cb7-ab43-47ce-8904-4f39f745c855","type":"Circle"},{"attributes":{"items":[{"id":"18acd4ea-649c-4f8f-ade0-bfb5ff5dcf74","type":"LegendItem"},{"id":"e3ac9e12-0554-4318-9aef-2afca8faca34","type":"LegendItem"},{"id":"fc503c1a-ff17-4d5b-baf0-cdd3431a3a7e","type":"LegendItem"}],"location":"top_left","plot":{"id":"d5ab80dc-a4eb-4fa3-bc75-542a87079b9d","subtype":"Chart","type":"Plot"}},"id":"85ee7e87-5029-49df-8022-4e9646e3a6e6","type":"Legend"},{"attributes":{"axis_label":"Total Interest Income","formatter":{"id":"fec9230e-75a4-48e2-ae04-6de22e8b009e","type":"BasicTickFormatter"},"plot":{"id":"d5ab80dc-a4eb-4fa3-bc75-542a87079b9d","subtype":"Chart","type":"Plot"},"ticker":{"id":"c5a76423-2178-44bd-908d-150bf08e5ee4","type":"BasicTicker"}},"id":"951659d2-991c-4067-be15-76d3cb00358c","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"607d940a-fb6e-440f-8cad-874f1feecde0","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":"Total Interest Income by AGI Bin (Thousand of Dollars)"},"id":"35c027cc-1817-4358-8f62-370f467a52d3","type":"Title"},{"attributes":{"plot":{"id":"d5ab80dc-a4eb-4fa3-bc75-542a87079b9d","subtype":"Chart","type":"Plot"}},"id":"d644e9d3-0fa9-4037-8524-6010c1fddede","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI"],"chart_index":[{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":[4688264.0,541622.0,770262.0,1002678.0,1147555.0,1125760.0,1340811.0,2096189.0,1900496.0,5955852.0,5013047.0,13390182.0,12725861.0,6814230.0,3825975.0,2582189.0,7098608.0,4547632.0,17327068.0]}},"id":"7e04f72b-de5a-40f6-9dba-c8a506975ceb","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"607d940a-fb6e-440f-8cad-874f1feecde0","type":"BoxAnnotation"},"plot":{"id":"d5ab80dc-a4eb-4fa3-bc75-542a87079b9d","subtype":"Chart","type":"Plot"}},"id":"5d34965d-f257-46c9-a35a-1fe70dbcca80","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"7e04f72b-de5a-40f6-9dba-c8a506975ceb","type":"ColumnDataSource"},"glyph":{"id":"57def6ab-b013-46d9-8713-6417ebd8edba","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7e44df7d-c090-4251-a8db-fe8b5dd87702","type":"GlyphRenderer"},{"attributes":{"label":{"value":"TC-No Adjustment"},"renderers":[{"id ...
