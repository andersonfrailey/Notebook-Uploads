# %%
from taxcalc import *
from taxcalc.utils import *
from notebookfunctions import distribution, index_list
from bokeh.io import show, output_notebook
from bokeh.charts import Bar, Scatter, Histogram
from bokeh.layouts import column
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="326ad7b3-3a8f-4810-a839-bf5f64d968de">Loading BokehJS ...</span>
#     </div>

# %%
calc_sas = Calculator(records=taxcalc.Records(), policy=Policy())
calc_sas.advance_to_year(2017)
calc_sas.calc_all()
# Out:
# You loaded data for 2009.
# Tax-Calculator startup automatically extrapolated your data to 2013.

# %%
# Use CSV files associated with the python produced PUF
rec_py = Records('../taxdata/puf_data/puf.csv',
                 weights='../taxdata/puf_stage2/puf_weights.csv',
                 adjust_ratios='../taxdata/puf_stage3/puf_ratios.csv')
calc_py = Calculator(records=rec_py, policy=Policy())
calc_py.advance_to_year(2017)
calc_py.calc_all()
# Out:
# You loaded data for 2009.
# Your data include the following unused variables that will be ignored:
#   jcps88
#   jcps89
#   jcps80
#   jcps81
#   jcps82
#   jcps83
#   jcps84
#   jcps85
#   jcps86
#   jcps87
#   zwaspt
#   e52872
#   jcps19
#   jcps18
#   jcps17
#   jcps16
#   jcps15
#   jcps14
#   jcps13
#   jcps12
#   jcps11
#   jcps10
#   icps4
#   icps5
#   jcps68
#   jcps69
#   cweight
#   jcps63
#   jcps60
#   jcps61
#   jcps66
#   jcps67
#   jcps64
#   jcps65
#   cpsseq
#   jcps97
#   jcps96
#   jcps95
#   jcps94
#   jcps93
#   jcps92
#   jcps91
#   jcps90
#   jcps99
#   jcps98
#   soiseq
#   jcps79
#   jcps78
#   wt
#   jcps71
#   jcps70
#   jcps73
#   jcps72
#   jcps75
#   jcps74
#   jcps77
#   jcps76
#   jcps62
#   jcps44
#   jcps45
#   jcps46
#   jcps47
#   jcps40
#   jcps41
#   jcps42
#   jcps43
#   zwassp
#   jcps48
#   jcps49
#   p86421
#   prodseq
#   jcps53
#   jcps52
#   jcps51
#   jcps50
#   jcps57
#   jcps56
#   jcps55
#   jcps54
#   jcps59
#   jcps58
#   icps6
#   jcps4
#   finalseq
#   jcps100
#   e07140
#   jcps26
#   jcps27
#   jcps24
#   jcps25
#   jcps22
#   jcps23
#   jcps20
#   jcps21
#   jcps28
#   jcps29
#   e52852
#   jcps35
#   jcps34
#   jcps37
#   jcps36
#   jcps31
#   jcps30
#   jcps33
#   jcps32
#   jcps39
#   jcps38
#   jcps7
#   jcps6
#   jcps5
#   icps7
#   jcps3
#   jcps2
#   jcps1
#   icps3
#   icps8
#   icps9
#   jcps9
#   jcps8
# Tax-Calculator startup automatically extrapolated your data to 2013.

# %% [markdown]
# ### Diagnostic Tables

# %%
# Create Diagnostic Tables for both
print 'Diagnostic Table - Current'
create_diagnostic_table(calc_sas)
# Out:
# Diagnostic Table - Current
#                                    2017
# Returns (#m)                      170.4
# AGI ($b)                       11,440.8
# Itemizers (#m)                     44.8
# Itemized Deduction ($b)         1,268.7
# Standard Deduction Filers (#m)    111.9
# Standard Deduction ($b)           996.2
# Personal Exemption ($b)         1,175.7
# Taxable Income ($b)             8,492.6
# Regular Tax ($b)                1,777.1
# AMT Income ($b)                10,822.0
# AMT Liability ($b)                 44.9
# AMT Filers (#m)                     5.6
# Tax before Credits ($b)         1,822.0
# Refundable Credits ($b)            96.5
# Nonrefundable Credits ($b)         74.6
# Reform Surtaxes ($b)                0.0
# Other Taxes ($b)                   48.8
# Ind Income Tax ($b)             1,699.8
# Payroll Taxes ($b)              1,093.5
# Combined Liability ($b)         2,793.3
# With Income Tax <= 0 (#m)          71.2
# With Combined Tax <= 0 (#m)        41.7

# %%
print 'Diagnostic Table - Python Created PUF'
create_diagnostic_table(calc_py)
# Out:
# Diagnostic Table - Python Created PUF
#                                    2017
# Returns (#m)                      170.1
# AGI ($b)                       11,445.3
# Itemizers (#m)                     44.6
# Itemized Deduction ($b)         1,269.8
# Standard Deduction Filers (#m)    111.9
# Standard Deduction ($b)           985.9
# Personal Exemption ($b)         1,173.9
# Taxable Income ($b)             8,502.1
# Regular Tax ($b)                1,777.5
# AMT Income ($b)                10,827.8
# AMT Liability ($b)                 45.7
# AMT Filers (#m)                     5.7
# Tax before Credits ($b)         1,823.3
# Refundable Credits ($b)            96.8
# Nonrefundable Credits ($b)         74.8
# Reform Surtaxes ($b)                0.0
# Other Taxes ($b)                   48.5
# Ind Income Tax ($b)             1,700.2
# Payroll Taxes ($b)              1,090.5
# Combined Liability ($b)         2,790.6
# With Income Tax <= 0 (#m)          70.8
# With Combined Tax <= 0 (#m)        41.7

# %%
# Create differences table
print 'Differences Table'
create_difference_table(calc_sas.records, calc_py.records, 'weighted_deciles')
# Out:
# Differences Table
#         tax_cut    tax_inc       count       mean          tot_change  \
# 0     4,436,480  5,521,940  17,005,082        723      12,288,619,553
# 1     6,125,110  8,204,029  17,005,223        350       5,959,787,242
# 2     6,408,155  8,579,576  17,005,887        448       7,616,627,689
# 3     6,252,367  9,413,897  17,004,847        361       6,139,867,476
# 4     6,900,731  9,344,052  17,006,159        339       5,765,839,435
# 5     7,945,091  8,744,487  17,005,536        298       5,068,665,636
# 6     6,023,165 10,904,481  17,004,895      1,490      25,330,424,828
# 7     5,995,429 10,944,239  17,005,997      2,665      45,329,081,987
# 8     5,888,389 11,053,806  17,004,815      8,971     152,542,973,938
# 9    16,425,094    576,929  17,006,510 -3,610,208 -61,397,034,196,008
# sums 72,400,009 83,287,437 170,054,950        n/a -61,130,992,308,224
#
#      perc_inc perc_cut share_of_change aftertax_perc
# 0      32.47%   26.09%          -0.02%          nan%
# 1      48.24%   36.02%          -0.01%         1.33%
# 2      50.45%   37.68%          -0.01%         1.20%
# 3      55.36%   36.77%          -0.01%         1.12%
# 4      54.95%   40.58%          -0.01%         1.02%
# 5      51.42%   46.72%          -0.01%         0.53%
# 6      64.13%   35.42%          -0.04%         2.51%
# 7      64.36%   35.25%          -0.07%         3.03%
# 8      65.00%   34.63%          -0.25%         6.89%
# 9       3.39%   96.58%         100.44%       -42.70%
# sums      n/a      n/a         100.00%           n/a

# %% [markdown]
# ## Distribution of Income Variables - Percentage in Each AGI Bin

# %%
sas_dist = pd.DataFrame()
py_dist = pd.DataFrame()
sas_was = distribution(calc_sas.records.e00200, calc_sas.records.s006, calc_sas.records.c00100)
sas_int = distribution(calc_sas.records.e00300, calc_sas.records.s006, calc_sas.records.c00100)
sas_odiv = distribution(calc_sas.records.e00600, calc_sas.records.s006, calc_sas.records.c00100)
sas_qdiv = distribution(calc_sas.records.e00650, calc_sas.records.s006, calc_sas.records.c00100)
sas_biz = distribution(calc_sas.records.e00900, calc_sas.records.s006, calc_sas.records.c00100)
sas_combined = distribution(calc_sas.records.combined, calc_sas.records.s006, calc_sas.records.c00100)
py_was = distribution(calc_py.records.e00200, calc_py.records.s006, calc_py.records.c00100)
py_int = distribution(calc_py.records.e00300, calc_py.records.s006, calc_py.records.c00100)
py_odiv = distribution(calc_py.records.e00600, calc_py.records.s006, calc_py.records.c00100)
py_qdiv = distribution(calc_py.records.e00650, calc_py.records.s006, calc_py.records.c00100)
py_biz = distribution(calc_py.records.e00900, calc_py.records.s006, calc_py.records.c00100)
py_combined = distribution(calc_py.records.combined, calc_py.records.s006, calc_py.records.c00100)
sas_dist['WAS'] = sas_was[1]
sas_dist['INT'] = sas_int[1]
sas_dist['ODIV'] = sas_odiv[1]
sas_dist['QDIV'] = sas_qdiv[1]
sas_dist['BIZ'] = sas_biz[1]
sas_dist['combined'] = sas_combined[1]
sas_dist['AGI Bin'] = index_list()
sas_dist['label'] = 'SAS'
py_dist['WAS'] = py_was[1]
py_dist['INT'] = py_int[1]
py_dist['ODIV'] = py_odiv[1]
py_dist['QDIV'] = py_qdiv[1]
py_dist['BIZ'] = py_biz[1]
py_dist['combined'] = py_combined[1]
py_dist['AGI Bin'] = index_list()
py_dist['label'] = 'Python'
scatter_data = pd.concat([sas_dist, py_dist])
# Create scatter plot objects for each variable
items_tups = [('WAS', 'WAS'), ('INT', 'Interest Income'), ('ODIV', 'Ordinary Dividends'),
              ('QDIV', 'Qualified Dividends'), ('BIZ', 'Business Income'), ('combined', 'Combined Tax Liability')]
scatter_list = list()  # list for scatter plot objects
for item in items_tups:
    title = 'Percent of Total {} by AGI Bin'.format(item[1])
    scatter = Scatter(scatter_data, x='AGI Bin', y=item[0], color='label', ylabel='Percent',
                      title=title, tooltips=[('PCT', '@{}'.format(item[0]))])
    scatter_list.append(scatter)

# %%
show(column(scatter_list))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3483b3b9-ca7a-4128-8cb5-2e17e292a1ef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3483b3b9-ca7a-4128-8cb5-2e17e292a1ef").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3483b3b9-ca7a-4128-8cb5-2e17e292a1ef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3483b3b9-ca7a-4128-8cb5-2e17e292a1ef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b2ef3962-a427-44e4-a27e-9c825449008d":{"roots":{"references":[{"attributes":{},"id":"f408ba2b-fb1a-4d02-80f7-dfa42dbbd3ea","type":"ToolEvents"},{"attributes":{"label":{"value":"SAS"},"renderers":[{"id":"1995c997-c2e2-4d48-a581-7455b19c40af","type":"GlyphRenderer"}]},"id":"2da8503d-6bae-437c-9968-00eb63410c1a","type":"LegendItem"},{"attributes":{"plot":{"id":"2a9c0651-3163-468a-8975-0198f966da90","subtype":"Chart","type":"Plot"}},"id":"1bbdc52c-a51a-40af-8f38-73fdfaa10294","type":"ResetTool"},{"attributes":{"plot":{"id":"e8e62d17-3cef-4ce1-83ee-adaca56a8d8b","subtype":"Chart","type":"Plot"},"ticker":{"id":"1fc3a71c-0e67-4fb2-8d5e-e73bbbc27bcc","type":"CategoricalTicker"}},"id":"8b5b6bda-d1ea-4b2c-87b1-a854ceac70f8","type":"Grid"},{"attributes":{},"id":"37abaf50-b1b6-46f2-a3b2-5264418ef147","type":"CategoricalTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7f991191-aada-4886-81f5-8315e62abfbe","type":"BoxAnnotation"},{"attributes":{"callback":null,"plot":{"id":"e8e62d17-3cef-4ce1-83ee-adaca56a8d8b","subtype":"Chart","type":"Plot"},"tooltips":[["PCT","@ODIV"]]},"id":"9fe7927c-1d52-41b0-8e1e-137f578328e2","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values","INT"],"data":{"INT":{"__ndarray__":"H4XrUbgeD0AfhetRuB4PQIXrUbgehfM/SOF6FK5H9T97FK5H4Xr0P1K4HoXrUfA/AAAAAAAA8D+F61G4HoX/P1yPwvUoXPs/7FG4HoXrEkBcj8L1KFwRQM3MzMzMTCpA4XoUrkfhKUApXI/C9SggQK5H4XoUrg1A4XoUrkfhBkAfhetRuB4gQDMzMzMzMxNA4XoUrkehNkA=","dtype":"float64","shape":[19]},"chart_index":[{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"},{"label":"Python"}],"label":["Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python","Python"],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":{"__ndarray__":"H4XrUbgeD0AfhetRuB4PQIXrUbgehfM/SOF6FK5H9T97FK5H4Xr0P1K4HoXrUfA/AAAAAAAA8D+F61G4HoX/P1yPwvUoXPs/7FG4HoXrEkBcj8L1KFwRQM3MzMzMTCpA4XoUrkfhKUApXI/C9SggQK5H4XoUrg1A4XoUrkfhBkAfhetRuB4gQDMzMzMzMxNA4XoUrkehNkA=","dtype":"float64","shape":[19]}}},"id":"b92d210b-bb4e-4be4-9ed2-99084133ccf5","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"95f25303-384f-4a70-a7c6-4775717751fa","subtype":"Chart","type":"Plot"}},"id":"6595d612-ec1c-436c-9432-a5efb48c7da7","type":"SaveTool"},{"attributes":{"axis_label":"Percent","formatter":{"id":"d746a75b-ac8b-4b24-9f7e-56394f698f51","type":"BasicTickFormatter"},"plot":{"id":"79cf3319-c30a-49a8-9988-eef79e04da32","subtype":"Chart","type":"Plot"},"ticker":{"id":"833d12a8-9623-4b0a-840c-904ba027edc3","type":"BasicTicker"}},"id":"2c811bc6-75a6-4086-b561-239b228c4f54","type":"LinearAxis"},{"attributes":{"callback":null,"end":17.379,"start":-0.2490000000000001},"id":"2bd3baf5-f78d-4497-84c2-da4b7d13c8b7","type":"Range1d"},{"attributes":{"plot":{"id":"e8e62d17-3cef-4ce1-83ee-adaca56a8d8b","subtype":"Chart","type":"Plot"}},"id":"b58519ef-a4ba-48a0-8953-419b68de18ce","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"2a9c0651-3163-468a-8975-0198f966da90","subtype":"Chart","type":"Plot"},"ticker":{"id":"eaa5803e-bfad-422a-add8-a3c9eed0fb97","type":"BasicTicker"}},"id":"e1d48b4e-0ee4-417f-90e4-ab4dd65f86f8","type" ...

# %% [markdown]
# ## Distribution of Income Variables - Total by Income Bin

# %%
sas_dist = pd.DataFrame()
py_dist = pd.DataFrame()
sas_dist['WAS'] = sas_was[0]
sas_dist['INT'] = sas_int[0]
sas_dist['ODIV'] = sas_odiv[0]
sas_dist['QDIV'] = sas_qdiv[0]
sas_dist['BIZ'] = sas_biz[0]
sas_dist['combined'] = sas_combined[0]
sas_dist['AGI Bin'] = index_list()
sas_dist['label'] = 'SAS'
py_dist['WAS'] = py_was[0]
py_dist['INT'] = py_int[0]
py_dist['ODIV'] = py_odiv[0]
py_dist['QDIV'] = py_qdiv[0]
py_dist['BIZ'] = py_biz[0]
py_dist['combined'] = py_combined[0]
py_dist['AGI Bin'] = index_list()
py_dist['label'] = 'Python'
scatter_data = pd.concat([sas_dist, py_dist])
# Create scatter plot object for each variable
items_tups = [('WAS', 'WAS'), ('INT', 'Interest Income'), ('ODIV', 'Ordinary Dividends'),
              ('QDIV', 'Qualified Dividends'), ('BIZ', 'Business Income'), ('combined', 'Combined Tax Liability')]
scatter_list = list()  # list for scatter plot objects
for item in items_tups:
    title = 'Total {} by AGI Bin'.format(item[1])
    scatter = Scatter(scatter_data, x='AGI Bin', y=item[0], color='label', ylabel='Percent',
                      title=title, tooltips=[('PCT', '@{}'.format(item[0]))])
    scatter_list.append(scatter)

# %%
show(column(scatter_list))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="10d724d9-932d-47f6-8262-fdafd5e55086"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("10d724d9-932d-47f6-8262-fdafd5e55086").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("10d724d9-932d-47f6-8262-fdafd5e55086");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '10d724d9-932d-47f6-8262-fdafd5e55086' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"27b7ed99-7bcf-4df0-9cf4-4d1fa8117b2a":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"672ca916-122a-4881-a5ec-70148c59f7d6","type":"PanTool"},{"id":"d544d787-1329-43bf-a92e-3f96f81b1c8b","type":"WheelZoomTool"},{"id":"e57e4bb3-a7ea-4ec0-bd28-6668da5e1e1c","type":"BoxZoomTool"},{"id":"f56e5d37-3c67-48d1-a7a4-6aa812e9faf5","type":"SaveTool"},{"id":"bbb5f6df-c1dc-40bd-a2ad-9b8b3262b9f4","type":"ResetTool"},{"id":"ef3bf225-47c8-427f-9bb4-09915e03458a","type":"HelpTool"},{"id":"4584a536-4eb4-40b5-80ab-06bee359a898","type":"HoverTool"}]},"id":"32bdcf5d-a4fa-47dc-a5f3-a334ac701f88","type":"Toolbar"},{"attributes":{"plot":{"id":"06893651-ad33-43e5-8331-7d73a9e2e33e","subtype":"Chart","type":"Plot"}},"id":"a1badf0c-d3f1-427a-8bf6-2c83f9627ec6","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e8c984ae-188a-489f-bba1-71a198da1d50","subtype":"Chart","type":"Plot"}},"id":"f56e5d37-3c67-48d1-a7a4-6aa812e9faf5","type":"SaveTool"},{"attributes":{"label":{"value":"Python"},"renderers":[{"id":"b0d7ba55-363b-4f7f-90f4-88b33879aeaf","type":"GlyphRenderer"}]},"id":"654bf686-7e75-416e-a458-300a2dcfff4a","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ca764731-a149-486d-8f37-bfe7b6e2cb54","type":"Circle"},{"attributes":{},"id":"1e0584df-03a8-45c1-aebc-9a222b42abac","type":"CategoricalTicker"},{"attributes":{},"id":"9b7145f1-b72c-4c26-ab0e-1aad2586811c","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"5d3895ea-1c02-4002-aa75-4d196835a83d","type":"Circle"},{"attributes":{"data_source":{"id":"7aeabbd2-07f4-4a6c-88aa-9b4b63f11fdf","type":"ColumnDataSource"},"glyph":{"id":"e6b5ee71-b2fc-4128-af87-69f8fbd7e975","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1004e3e3-3f18-4b13-bce9-07c93dccecb9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"88a4b4d2-6a79-4212-b1f5-53ae5edc0d96","subtype":"Chart","type":"Plot"}},"id":"cac380e7-0356-4c62-808a-f9646ddc9ff7","type":"HelpTool"},{"attributes":{"plot":{"id":"2b055325-b5d3-4ea6-a8dd-9c6d7de5749d","subtype":"Chart","type":"Plot"}},"id":"849a9d20-6f4f-4f91-a67e-4ea4c2b2b2a9","type":"HelpTool"},{"attributes":{},"id":"e0cce26b-6079-4852-8219-fcf4f240373b","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"10a45cff-bbe6-459c-b1da-8f1c59f8548d","subtype":"Chart","type":"Plot"}},"id":"d05660f5-6794-44b8-8410-688c925f88f5","type":"ResetTool"},{"attributes":{},"id":"05be29e7-0381-4915-bf4c-de7303ca34e3","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"81ef9f23-d7a8-43f4-b5a2-114ec732ac17","type":"ColumnDataSource"},"glyph":{"id":"111d1f1c-b1d3-4b55-ba8e-eef6bdedb7a6","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a0454944-e3cb-4ef6-9542-409ca1d39f07","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"10a45cff-bbe6-459c-b1da-8f1c59f8548d","subtype":"Chart","type":"Plot"}},"id":"bbf1450c-9d1d-4364-a798-66064cf18bd3","type":"HelpTool"},{"attributes":{"below":[{"id":"9f831eb7-ad77-4a95-84f0-f07115b4a2c0","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"0438d2c7-d9ef-4c3f-b36b-94135a9b8503","type":"LinearAxis"}],"renderers":[{"id":"bb7cfe41-8897-4e9d-9bf3-ba363c4cd388","type":"BoxAnnotation"},{"id":"de5d0fb0-f84f-490c-990b-9d182986ef04","type":"GlyphRenderer"},{"id":"b0d7ba55-363b-4f7f-90f4-88b33879aeaf","type":"GlyphRenderer"},{"id":"caffb40c-802a-41a5-a12b-7a54993a1553","type":"Legend"},{"id":"9f831eb7-ad77-4a95-84f0-f07115b4a2c0","type":"CategoricalAxis"},{"id":"0438d2c7-d9ef-4c3f-b36b-94135a9b8503","type":"LinearAxis"},{"id":"333e6297-486e-4cb ...

# %% [markdown]
# ## Itemized Deduction Amounts

# %%
deductions_sas = {'Medical Expenses': (calc_sas.records.e17500 * calc_sas.records.s006).sum(),
                  'State and Local Taxes':  (calc_sas.records.e18400 * calc_sas.records.s006).sum(),
                  'Real Estate Taxes':  (calc_sas.records.e18500 * calc_sas.records.s006).sum(),
                  'Interest Paid':  (calc_sas.records.e19200 * calc_sas.records.s006).sum(),
                  'Charitable Cash Contributions': (calc_sas.records.e19800 * calc_sas.records.s006).sum(),
                  'Charitable Non-Cash Contributions': (calc_sas.records.e20100 * calc_sas.records.s006).sum(),
                  'Total Misc. Expenses':  (calc_sas.records.e20400* calc_sas.records.s006).sum(),
                  'Net Casualty or Loss': (calc_sas.records.e20500 * calc_sas.records.s006).sum()}
ded_sas_df = pd.DataFrame.from_dict(deductions_sas, 'index')
ded_sas_df.columns = ['Total']
ded_sas_df['source'] = 'SAS'

deductions_py = {'Medical Expenses': (calc_py.records.e17500 * calc_py.records.s006).sum(),
                  'State and Local Taxes':  (calc_py.records.e18400 * calc_py.records.s006).sum(),
                  'Real Estate Taxes':  (calc_py.records.e18500 * calc_py.records.s006).sum(),
                  'Interest Paid':  (calc_py.records.e19200 * calc_py.records.s006).sum(),
                  'Charitable Cash Contributions': (calc_py.records.e19800 * calc_py.records.s006).sum(),
                  'Charitable Non-Cash Contributions': (calc_py.records.e20100 * calc_py.records.s006).sum(),
                  'Total Misc. Expenses':  (calc_py.records.e20400* calc_py.records.s006).sum(),
                  'Net Casualty or Loss': (calc_py.records.e20500 * calc_py.records.s006).sum()}
ded_py_df = pd.DataFrame.from_dict(deductions_py, 'index')
ded_py_df.columns = ['Total']
ded_py_df['source'] = 'Python'

ded_full_df = pd.concat([ded_sas_df, ded_py_df])
ded_full_df['index'] = ded_full_df.index

# %%
ded_bar = Bar(ded_full_df, 'index', 'Total', group='source', title='Itemized Deduction Totals',
              xlabel='Deduction', ylabel='Total', tooltips=[('Deduction', '@index'), ('Total', '@height'),
                                                            ('Data', '@source')])
show(ded_bar)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="01748e8f-495d-4877-b69f-c1b6f8740bb8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("01748e8f-495d-4877-b69f-c1b6f8740bb8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01748e8f-495d-4877-b69f-c1b6f8740bb8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01748e8f-495d-4877-b69f-c1b6f8740bb8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d7e317b5-b51d-4d53-95ac-9fa4b3fbe974":{"roots":{"references":[{"attributes":{"data_source":{"id":"d66df79b-c3bd-4226-b099-d42b01759df4","type":"ColumnDataSource"},"glyph":{"id":"d6af8144-2600-4931-b653-d79261fe3378","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"13d4e7dc-4abe-4be2-8203-2f5690f8e3e3","type":"GlyphRenderer"},{"attributes":{"axis_label":"Total","formatter":{"id":"e926da8b-6f01-4cd2-95d3-521a92dab836","type":"BasicTickFormatter"},"plot":{"id":"d443453f-fdc0-44c8-9f98-dee8a8d2f712","subtype":"Chart","type":"Plot"},"ticker":{"id":"2ea1f160-9b74-4783-bd15-7c6eda9f49c6","type":"BasicTicker"}},"id":"81167b61-da50-4f72-82f7-0a138b5cd1d6","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4a1f0d1b-be2d-42df-827f-e02bd60db34e","type":"BoxAnnotation"},{"attributes":{"callback":null,"plot":{"id":"d443453f-fdc0-44c8-9f98-dee8a8d2f712","subtype":"Chart","type":"Plot"},"tooltips":[["Deduction","@index"],["Total","@height"],["Data","@source"]]},"id":"df481ed3-78e1-4f3f-a71a-1a82763e7225","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"Medical Expenses","source":"Python"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[160083325255.08334],"index":["Medical Expenses"],"label":[{"index":"Medical Expenses","source":"Python"}],"line_alpha":[1.0],"line_color":["white"],"source":["Python"],"width":[0.2],"x":["Medical Expenses:0.666666666667"],"y":[80041662627.54167]}},"id":"c716ebbd-cc2b-4bbd-bd9b-c319c4388241","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"360dab0c-b8e1-415e-a5a7-7d9a35c03393","type":"ColumnDataSource"},"glyph":{"id":"ac46bb08-5948-44ab-906a-fc86920b9102","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4cf8aea2-8d6e-412b-8e72-24badad33903","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"Charitable Cash Contributions","source":"SAS"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[178295489777.88254],"index":["Charitable Cash Contributions"],"label":[{"index":"Charitable Cash Contributions","source":"SAS"}],"line_alpha":[1.0],"line_color":["white"],"source":["SAS"],"width":[0.2],"x":["Charitable Cash Contributions:0.333333333333"],"y":[89147744888.94127]}},"id":"d66df79b-c3bd-4226-b099-d42b01759df4","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"24f628e9-f174-4ca0-a554-0ccea8162b49","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"81167b61-da50-4f72-82f7-0a138b5cd1d6","type":"LinearAxis"}],"renderers":[{"id":"4a1f0d1b-be2d-42df-827f-e02bd60db34e","type":"BoxAnnotation"},{"id":"6615e36d-0893-4bc2-b88b-bd4f1ba8a54f","type":"GlyphRenderer"},{"id":"6a12300b-1bdb-4f4d-adac-a55d65da0e72","type":"GlyphRenderer"},{"id":"623cfa3c-b77f-4a3e-8141-8e73b43133f1","type":"GlyphRenderer"},{"id":"5fe2719e-d28d-4a02-85ca-4f515b1baa45","type":"GlyphRenderer"},{"id":"06175edc-b879-42a0-b172-79101bfbae39","type":"GlyphRenderer"},{"id":"7f9dae09-c301-4be0-b900-250d081c1837","type":"GlyphRenderer"},{"id":"13d4e7dc-4abe-4be2-8203-2f5690f8e3e3","type":"GlyphRenderer"},{"id":"b1297cb5-b0e0-4047-9332-9fce72fbed5a","type":"GlyphRenderer"},{"id":"0441822e-8f81-4a50-b05a-1436ea727f3f","type":"GlyphRenderer"},{"id":"4cf8aea2-8d6e-412b-8e72-24badad33903","type":"GlyphRenderer"},{"id":"7d90020e-5e0a-4d84-b4b5-d1216cd0bb3d","type":"GlyphRenderer"},{"id":"f0b706f4-8e11-4483-99e1-4a8f5dbbf4c5","type":"GlyphRenderer"},{"id":"75bd0c88-b6eb-4198-8 ...

# %% [markdown]
# ### Number of Filers and Non-Filers

# %%
filers_py = (calc_py.records.filer * calc_py.records.s006).sum()
filers_sas = (calc_sas.records.filer * calc_sas.records.s006).sum()
nonfilers_py = (calc_py.records.s006[calc_py.records.filer == 0]).sum()
nonfilers_sas = (calc_sas.records.s006[calc_sas.records.filer == 0]).sum()
print '# Filers, Python: {}'.format(filers_py)
print '# Filers, SAS:    {}'.format(filers_sas)
print '# Non-Filers, Python: {}'.format(nonfilers_py)
print '# Non-Filers, SAS:    {}'.format(nonfilers_sas)
# Out:
# # Filers, Python: 153581131.61
# # Filers, SAS:    153581143.76
# # Non-Filers, Python: 16473818.8
# # Non-Filers, SAS:    16838366.52

# %%
nonfilers_py / nonfilers_sas
# Out:
# 0.9783501731259371

# %% [markdown]
# ### Age Distribution

# %%
agediff_sas = pd.DataFrame(calc_sas.records.age_head[calc_sas.records.MARS == 2] -
                           calc_sas.records.age_spouse[calc_sas.records.MARS == 2]).apply(lambda x: abs(x))
agediff_sas.columns = ['Age Difference']
agediff_sas['Calc'] = 'SAS'
agediff_py = pd.DataFrame(calc_py.records.age_head[calc_py.records.MARS == 2] -
                          calc_py.records.age_spouse[calc_py.records.MARS == 2]).apply(lambda x: abs(x))
agediff_py.columns = ['Age Difference']
agediff_py['Calc'] = 'Python'
agediffs = pd.concat([agediff_sas, agediff_py])

# %%
show(Histogram(agediffs, 'Age Difference', color='Calc', legend='top_right', bins=20,
               tooltips=[('Count', '@height')]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8da3fdc7-b47d-44ad-a17a-1b04d007ed01"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8da3fdc7-b47d-44ad-a17a-1b04d007ed01").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8da3fdc7-b47d-44ad-a17a-1b04d007ed01");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8da3fdc7-b47d-44ad-a17a-1b04d007ed01' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2d60f4d3-4f28-47a7-9a59-73f3c262ada3":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(46.200000, 50.400000]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[59.0],"label":["(46.200000, 50.400000]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.200000000000003],"x":["48.3"],"y":[29.5]}},"id":"61eac7c8-a4ef-41ee-aa4c-9b398a8c8c34","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(6.300000, 7.200000]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[4564.0],"label":["(6.300000, 7.200000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.9000000000000004],"x":["6.75"],"y":[2282.0]}},"id":"2c61ad9f-3713-44ee-89fe-52646ef082e3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2a168cca-038b-4ba0-8161-69c4ec1105ff","type":"ColumnDataSource"},"glyph":{"id":"3aa55574-9b3f-4b0d-b62c-560ea3ea3dc1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3ef2f4ff-8059-4cd2-87a7-776f3aa4ef82","type":"GlyphRenderer"},{"attributes":{"items":[{"id":"3c92f54b-b89d-499e-95fa-b114632bddf0","type":"LegendItem"},{"id":"8bb19d41-cb3a-4299-8673-041c3c7079d3","type":"LegendItem"}],"plot":{"id":"b426280c-0b52-4def-9d69-bd98be243e96","subtype":"Chart","type":"Plot"}},"id":"0f9a5bcb-cc7e-4882-a6d7-4dd577b52b31","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"890b664b-061b-4b94-a4f2-30a4e295d667","type":"Rect"},{"attributes":{},"id":"166d9d48-6a35-4cf7-a671-af4022dabcb1","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"60ba736b-4005-44fd-aa16-714140c222c5","type":"ColumnDataSource"},"glyph":{"id":"93e2c572-4c25-49eb-b048-75d7ac0cda76","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7ff7073e-1db5-4def-aaf0-27415f8f7258","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(37.800000, 42.000000]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[208.0],"label":["(37.800000, 42.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.199999999999996],"x":["39.9"],"y":[104.0]}},"id":"55c63029-7be7-4fcd-acec-747a88719466","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be52eb30-a98b-4766-a5ea-0db01bb0c1bb","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(75.600000, 79.800000]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[518.0],"label":["(75.600000, 79.800000]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.199999999999989],"x":["77.7"],"y":[259.0]}},"id":"60ba736b-4005-44fd-aa16-714140c222c5","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4f9ba042-029f-4619-9298-b6e8d232da5b","type":"Rect"},{"attributes":{"callback":null,"end":86.1,"start":-2.1},"id":"8e48d674-7f07-4cce-83cc-97c291ca3c7d","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"l ...

# %%
print 'Maximum Age Difference, SAS:    {}'.format(agediff_sas['Age Difference'].max())
print 'Maximum Age Difference, Python: {}'.format(agediff_py['Age Difference'].max())
print 'Minimum Age Difference, SAS:    {}'.format(agediff_sas['Age Difference'].min())
print 'Minimum Age Difference, Python: {}'.format(agediff_py['Age Difference'].min())
# Out:
# Maximum Age Difference, SAS:    84
# Maximum Age Difference, Python: 18
# Minimum Age Difference, SAS:    0
# Minimum Age Difference, Python: 0
